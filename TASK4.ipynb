# %% [markdown]
# <a href="https://colab.research.google.com/github/pavanteja41/tasks-for-data-science/blob/TASK4/TASK4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.read_csv("/content/Col@1.csv")
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 79    KarthikeyanS    45.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 82    mohamed nabi     0.0    0.0                  0               0
# 83  yaser ahamed.A     0.0   27.0                  0               0
#
#                                 Department  Rising
# 0         Computer Science and Engineering       0
# ...

# %%
pd.read_csv("/content/Col@2.csv")
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0            ASHOK KUMAR K     100          0     31                       9
# 1                  Chandru       0         20      0                       0
# 2        Ganesh Ramkumar R      -1         55     24                       6
# 3          Bodipudi Harini      -1          0     35                      -1
# 4                VIINU V P      -1        100     24                      -1
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 7                Gowtham R      -1         60      4                       6
# 8                 shifak N      58          0      0                       0
# 9                  Balaji       -1        100     20                       0
# 10                Rushitha      -1         15     62                       9
# ...

# %%
d1=pd.read_csv("/content/Col@1.csv")

# %%
d2=pd.read_csv("/content/Col@2.csv")

# %% [markdown]
# CONCATENATING THE GIVEN CSV FILES BY CONVERTING THEM TO DATAFRAMES

# %%
res=d1.append(d2)

# %%
res
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering       0        NaN
# ...

# %%
score=res["CodeKata Score"]

# %%
score
# Out:
# 0     24500
# 1     21740
# 2     19680
# 3     10610
# 4      8980
#       ...
# 30     2380
# 31     1890
# 32     1720
# 33        0
# 34        0
# Name: CodeKata Score, Length: 119, dtype: int64

# %%
ls=score.tolist()
ls
# Out:
# [24500,
#  21740,
#  19680,
#  10610,
#  8980,
#  8200,
#  7880,
#  7020,
#  5860,
#  5500,
#  5400,
#  5380,
#  5280,
#  5120,
#  4800,
#  4600,
#  4510,
#  4370,
#  4320,
#  4090,
#  3915,
#  3665,
#  3460,
#  3280,
#  3200,
#  3200,
#  3110,
#  3000,
#  2570,
#  2410,
#  2360,
#  2260,
#  2240,
#  2160,
#  1910,
#  1910,
#  1900,
#  1880,
#  1880,
#  1740,
#  1680,
#  1580,
#  1580,
#  1440,
#  1350,
#  1320,
#  1240,
#  1130,
#  1100,
#  1020,
#  980,
#  950,
#  850,
#  800,
#  770,
#  760,
#  720,
#  690,
#  580,
#  490,
#  410,
#  380,
#  300,
#  270,
#  260,
#  200,
#  180,
#  170,
#  160,
#  120,
#  120,
#  120,
#  120,
#  100,
#  100,
#  60,
#  40,
#  40,
#  40,
#  0,
#  0,
#  0,
#  0,
#  0,
#  19400,
#  14490,
#  10790,
#  10040,
#  9150,
#  8970,
#  8950,
#  8650,
#  8320,
#  8160,
#  8090,
#  8050,
#  8030,
#  7940,
#  7730,
#  7640,
#  7630,
#  7550,
#  6800,
#  6640,
#  6290,
#  6090,
#  5740,
#  5200,
#  5050,
#  4820,
#  4440,
#  4170,
#  4020,
#  3220,
#  2380,
# ...

# %% [markdown]
# SAVING THE VALUES INTO FILES BASED ON CODEKATA SCORE --EXCEEDED EXPECTATIONS, REACHED EXPECTATIONS, NEEDS IMPROVEMENT AND UNSATISFACTORY

# %%
for i in range(len(ls)):
  if (ls[i]>15000):
    dfee=res.iloc[i]
    dfee.to_csv('Exceeded_expectations.csv', mode='a', index=False, header=False)
  elif ((ls[i]>10000) and (ls[i]<15000)):
    dfre=res.iloc[i]
    dfre.to_csv('Reached_expectations.csv', mode='a', index=False, header=False)
  elif ((ls[i]>7000) and (ls[i]<10000)):
    dfni=res.iloc[i]
    dfni.to_csv('Needs_improvement.csv', mode='a', index=False, header=False)
  elif (ls[i]<7000):
    dfu=res.iloc[i]
    dfu.to_csv('Unsatisfactory.csv', mode='a', index=False, header=False)
  else:
    print("0")

# %%
avgs=res["python"]

# %%
avgls=avgs.tolist()

# %%
np.mean(avgls)
# Out:
# 54.35294117647059

# %%
ls
# Out:
# [24500,
#  21740,
#  19680,
#  10610,
#  8980,
#  8200,
#  7880,
#  7020,
#  5860,
#  5500,
#  5400,
#  5380,
#  5280,
#  5120,
#  4800,
#  4600,
#  4510,
#  4370,
#  4320,
#  4090,
#  3915,
#  3665,
#  3460,
#  3280,
#  3200,
#  3200,
#  3110,
#  3000,
#  2570,
#  2410,
#  2360,
#  2260,
#  2240,
#  2160,
#  1910,
#  1910,
#  1900,
#  1880,
#  1880,
#  1740,
#  1680,
#  1580,
#  1580,
#  1440,
#  1350,
#  1320,
#  1240,
#  1130,
#  1100,
#  1020,
#  980,
#  950,
#  850,
#  800,
#  770,
#  760,
#  720,
#  690,
#  580,
#  490,
#  410,
#  380,
#  300,
#  270,
#  260,
#  200,
#  180,
#  170,
#  160,
#  120,
#  120,
#  120,
#  120,
#  100,
#  100,
#  60,
#  40,
#  40,
#  40,
#  0,
#  0,
#  0,
#  0,
#  0,
#  19400,
#  14490,
#  10790,
#  10040,
#  9150,
#  8970,
#  8950,
#  8650,
#  8320,
#  8160,
#  8090,
#  8050,
#  8030,
#  7940,
#  7730,
#  7640,
#  7630,
#  7550,
#  6800,
#  6640,
#  6290,
#  6090,
#  5740,
#  5200,
#  5050,
#  4820,
#  4440,
#  4170,
#  4020,
#  3220,
#  2380,
# ...

# %%
top_list=np.sort(ls)[::-1]
top_list
x=top_list[0]
y=top_list[1]
z=top_list[2]

# %%
for i in range(len(ls)):
  if x==ls[i]:
    index1=i
for i in range(len(ls)):
  if y==ls[i]:
    index2=i
for i in range(len(ls)):
  if z==ls[i]:
    index3=i

# %% [markdown]
# RISING STARS  OF THE WEEK

# %%
first=res.iloc[index1]
second=res.iloc[index2]
third=res.iloc[index3]
print(first,"\n",second,"\n",third)
# Out:
# Name                                             A.Dharani
# python                                                82.0
# mysql                                                 20.0
# Previous Geekions                                    24500
# CodeKata Score                                       24500
# Department                Computer Science and Engineering
# Rising                                                   0
# python_en                                              NaN
# computational_thinking                                 NaN
# Name: 0, dtype: object
#  Name                                           V.JEEVITHA
# python                                                82.0
# mysql                                                 20.0
# Previous Geekions                                    21740
# CodeKata Score                                       21740
# Department                Computer Science and Engineering
# ...

# %% [markdown]
# SHINING STARS OF THE WEEK

# %%
geekcoins_series=res["Previous Geekions"]
geekcoins_list=geekcoins_series.tolist()
geekcoins_listcopy=geekcoins_series.tolist()
top_list_gc=np.sort(geekcoins_list)[::-1]
x=top_list_gc[0]
y=top_list_gc[1]
z=top_list_gc[2]
for i in range(len(geekcoins_list)):
  if x==geekcoins_list[i]:
    fss=i
for i in range(len(geekcoins_list)):
  if y==geekcoins_list[i]:
    sss=i
for i in range(len(geekcoins_list)):
  if z==geekcoins_list[i]:
    tss=i
print(res.iloc[fss],"\n",res.iloc[sss],"\n",res.iloc[tss])
# Out:
# Name                                             A.Dharani
# python                                                82.0
# mysql                                                 20.0
# Previous Geekions                                    24500
# CodeKata Score                                       24500
# Department                Computer Science and Engineering
# Rising                                                   0
# python_en                                              NaN
# computational_thinking                                 NaN
# Name: 0, dtype: object
#  Name                                           V.JEEVITHA
# python                                                82.0
# mysql                                                 20.0
# Previous Geekions                                    21740
# CodeKata Score                                       21740
# Department                Computer Science and Engineering
# ...
